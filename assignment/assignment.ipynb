# %% [markdown]
# # Lecture 5 - OPTIONAL NOT GRADED Basic Spark ML Assignement

# %% [markdown]
# ### Overview and Goal

# %% [markdown]
# In this assignment, you will analyze fitness tracker data collected from multiple users over several days. The dataset contains daily records of physical activities and health-related metrics, including steps taken, calories burned, distance traveled, active minutes, sleep hours, average heart rate, workout type, weather conditions, location, and self-reported mood.
#
# The goal of this assignment is to demonstrate your ability to apply big data analytics and machine learning techniques using PySpark. You will practice building machine learning pipelines including data cleaning, feature engineering, model training, evaluation, and interpretation for different types of tasks:
#
# **You will perform the following tasks using PySpark:**
#
#   1) Preprocess and clean the dataset. For each of the three following steps do: Evaluate the results for a fitness company and give a business use case where this might be valuable knowledge and put it into context.
#   2) Build a regression model to predict the number of calories burned based on users physical activity and contextual features, and evaluate model performance with appropriate metrics.
#   3) Develop a classification model to predict users mood using their activity patterns and environmental conditions, and evaluate model performance with appropriate metrics.
#   4) Apply clustering techniques to discover natural groupings in the users activity data, helping to identify patterns or user segments without using labeled outcomes. Determine the optimal number of clusters and visualise the results.
#
# By completing these tasks, you will gain hands-on experience in handling real-world fitness data. If you are already familiar with Spark machine learning feel free to change or improve upon these tasks or create your own more challenging tasks.
#
# **Important:** The goal for you is not to build the best and most optimal machine learning model there is, but to gain knowledge and experience. Interpret your results and if something is not working or does not provide relevant results, explain why, e.g. a model does not give useful information as the input data might not have enough to predict this accurately

# %% [markdown]
# ### Dataset and configs

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("spark_fitness_prediction_(student_name)") \
    .master("local[*]") \
    .getOrCreate()

#  \.master("spark://172.29.16.102:7077") \

# %% [markdown]
# Download the dataset from: https://www.kaggle.com/datasets/smayanj/fitness-tracker-dataset?resource=download

# %%
fitness_df = spark.read.csv("<path_to_your_file>/fitness_tracker_dataset.csv", header=True, inferSchema=True)
fitness_df.show(5)

# %% [markdown]
# ### Exploration

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# ### Excercise 1: Regression

# %% [markdown]
# ### Excercise 2: Classification

# %% [markdown]
# ### Excercise 3: Clustering
